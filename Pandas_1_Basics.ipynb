# %%
import pandas as pd

# %%
from_file=pd.read_csv('player_html.csv')

# %%
# its a binary file format, it convert data into bytecode and then it will store in the systemm
from_file.to_pickle('myPickle')

# %%
pwd()
# Out:
# 'C:\\Users\\lenovo\\Desktop\\Python\\dataAnalysis'

# %%
from_file
# Out:
#     Unnamed: 0      Season   Age   Tm   Lg  Pos       G     GS       MP  \
# 0            0     1969-70  22.0  MIL  NBA    C    82.0    NaN   3534.0
# 1            1     1970-71  23.0  MIL  NBA    C    82.0    NaN   3288.0
# 2            2     1971-72  24.0  MIL  NBA    C    81.0    NaN   3583.0
# 3            3     1972-73  25.0  MIL  NBA    C    76.0    NaN   3254.0
# 4            4     1973-74  26.0  MIL  NBA    C    81.0    NaN   3548.0
# 5            5     1974-75  27.0  MIL  NBA    C    65.0    NaN   2747.0
# 6            6     1975-76  28.0  LAL  NBA    C    82.0    NaN   3379.0
# 7            7     1976-77  29.0  LAL  NBA    C    82.0    NaN   3016.0
# 8            8     1977-78  30.0  LAL  NBA    C    62.0    NaN   2265.0
# 9            9     1978-79  31.0  LAL  NBA    C    80.0    NaN   3157.0
# 10          10     1979-80  32.0  LAL  NBA    C    82.0    NaN   3143.0
# 11          11     1980-81  33.0  LAL  NBA    C    80.0    NaN   2976.0
# ...

# %%
# store data into h5 file format
h5_data=pd.HDFStore('h5file.h5')

# %%
h5_data
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: h5file.h5

# %%
h5_data['age_ob']=from_file
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_2336\797707656.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos'], dtype='object')]
#
#   h5_data['age_ob']=from_file

# %%
h5_data['age_ob']
# Out:
#     Unnamed: 0      Season   Age   Tm   Lg  Pos       G     GS       MP  \
# 0            0     1969-70  22.0  MIL  NBA    C    82.0    NaN   3534.0
# 1            1     1970-71  23.0  MIL  NBA    C    82.0    NaN   3288.0
# 2            2     1971-72  24.0  MIL  NBA    C    81.0    NaN   3583.0
# 3            3     1972-73  25.0  MIL  NBA    C    76.0    NaN   3254.0
# 4            4     1973-74  26.0  MIL  NBA    C    81.0    NaN   3548.0
# 5            5     1974-75  27.0  MIL  NBA    C    65.0    NaN   2747.0
# 6            6     1975-76  28.0  LAL  NBA    C    82.0    NaN   3379.0
# 7            7     1976-77  29.0  LAL  NBA    C    82.0    NaN   3016.0
# 8            8     1977-78  30.0  LAL  NBA    C    62.0    NaN   2265.0
# 9            9     1978-79  31.0  LAL  NBA    C    80.0    NaN   3157.0
# 10          10     1979-80  32.0  LAL  NBA    C    82.0    NaN   3143.0
# 11          11     1980-81  33.0  LAL  NBA    C    80.0    NaN   2976.0
# ...

# %%
h5_data.put('age_ob2',from_file,format='table')

# %%
h5_data.select('age_ob2',where=['index>=10 and index<=15'])
# Out:
#     Unnamed: 0   Season   Age   Tm   Lg Pos     G    GS      MP     FG  ...  \
# 10          10  1979-80  32.0  LAL  NBA   C  82.0   NaN  3143.0  835.0  ...
# 11          11  1980-81  33.0  LAL  NBA   C  80.0   NaN  2976.0  836.0  ...
# 12          12  1981-82  34.0  LAL  NBA   C  76.0  76.0  2677.0  753.0  ...
# 13          13  1982-83  35.0  LAL  NBA   C  79.0  79.0  2554.0  722.0  ...
# 14          14  1983-84  36.0  LAL  NBA   C  80.0  80.0  2622.0  716.0  ...
# 15          15  1984-85  37.0  LAL  NBA   C  79.0  79.0  2630.0  723.0  ...
#
#       DRB    TRB    AST   STL    BLK    TOV     PF     PTS  Unnamed: 30  \
# 10  696.0  886.0  371.0  81.0  280.0  297.0  216.0  2034.0          NaN
# 11  624.0  821.0  272.0  59.0  228.0  249.0  244.0  2095.0          NaN
# 12  487.0  659.0  225.0  63.0  207.0  230.0  224.0  1818.0          NaN
# 13  425.0  592.0  200.0  61.0  170.0  200.0  220.0  1722.0          NaN
# 14  418.0  587.0  211.0  55.0  143.0  221.0  211.0  1717.0          NaN
# ...

# %%
titanic=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic.dtypes[titanic.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic.dtypes[titanic.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(titanic.dtypes[titanic.dtypes=='float64'])
# Out:
# pandas.core.series.Series

# %%
df1=titanic[titanic.dtypes[titanic.dtypes=='object'].index]

# %%
df1.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df2=titanic[titanic.dtypes[titanic.dtypes=='float64'].index]

# %%
df2
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df2.describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
titanic.dtypes[titanic.dtypes=='float64'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
titanic[['Fare','Age']]
# Out:
#         Fare   Age
# 0     7.2500  22.0
# 1    71.2833  38.0
# 2     7.9250  26.0
# 3    53.1000  35.0
# 4     8.0500  35.0
# ..       ...   ...
# 886  13.0000  27.0
# 887  30.0000  19.0
# 888  23.4500   NaN
# 889  30.0000  26.0
# 890   7.7500  32.0
#
# [891 rows x 2 columns]

# %%
titanic[['Name']][2:6:2]
# Out:
#                        Name
# 2    Heikkinen, Miss. Laina
# 4  Allen, Mr. William Henry

# %%
d=titanic['Name'].loc[[2,3,4]]

# %%
d
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
d[1:10:2]
# Out:
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Moran, Mr. James
# 7                       Palsson, Master. Gosta Leonard
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
d[20::-1]
# Out:
# 20                                 Fynney, Mr. Joseph J
# 19                              Masselmani, Mrs. Fatima
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 17                         Williams, Mr. Charles Eugene
# 16                                 Rice, Master. Eugene
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 13                          Andersson, Mr. Anders Johan
# 12                       Saundercock, Mr. William Henry
# 11                             Bonnell, Miss. Elizabeth
# 10                      Sandstrom, Miss. Marguerite Rut
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 7                        Palsson, Master. Gosta Leonard
# 6                               McCarthy, Mr. Timothy J
# 5                                      Moran, Mr. James
# 4                              Allen, Mr. William Henry
# ...

# %%
# sorting opertion
sorted(titanic['Ticket'])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
for i in titanic.columns:
    print(titanic[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# add one new coln in dataframe
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['tiku']='hey ! girl'

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['tiku1']=titanic['PassengerId']

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'tiku', 'tiku1'],
#       dtype='object')

# %%
pd.Categorical(titanic['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(titanic['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
titanic['avg']=titanic['tiku']*titanic['tiku1']

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to drop the coln from df
titanic.drop(columns='avg',inplace=True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'tiku', 'tiku1', 'mul'],
#       dtype='object')

# %%
# unique data
titanic['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
#to know null values
titanic['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
idx=titanic['Cabin'][titanic['Cabin'].isnull()==False]

# %%
idx.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %%
titanic['Cabin'].isnull()==True
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
titanic[titanic['Cabin'].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
titanic[titanic['Cabin'].isnull()==False].shape
# Out:
# (204, 15)

# %%
687+204
# Out:
# 891

# %%
# extract info row-wise
titanic.iloc[idx.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.loc[titanic[titanic['Age'].isnull()==True].index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.isnull()==True
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
# ...

# %%
titanic['Age'][titanic['Age'].isnull()==True].count
# Out:
# <bound method Series.count of 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
#        ..
# 859   NaN
# 863   NaN
# 868   NaN
# 878   NaN
# 888   NaN
# Name: Age, Length: 177, dtype: float64>

# %%
titanic[titanic['Fare']==max(titanic['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic['Name'][titanic['Fare']==titanic['Fare'].max()]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
titanic['Fare'].max()
# Out:
# 512.3292
